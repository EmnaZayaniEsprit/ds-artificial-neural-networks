# %% [markdown]
# # Overfit and Underfit

# %% [markdown]
# You have already learned about overfitting and underfitting in the context of machine learning algorithms. Unfortunately, these topics are also important when it comes to training an artificial neural network.
#
# You may have observed in previous notebooks that the accuracy(/mae) of your model on the validation set reaches a peak(/minimum) after training for a number of epochs and then stagnates or, worse, starts to decrease(/increase). This is a clear sign that the model is overfitting the training data.
#
# Artificial neural networks tend to overfit the data. It is possible to achieve extremely high accuracy (or low mae) on your training data if you just train your model long enough. However, this is not desirable because these models do not generalize well and will perform poorly on a test set or new data.
#
# Underfitting is another problem. If your model is not powerful enough, it is over-regularized, or it has not been trained long enough, it may perform poorly on the training and test set because it has not been able to learn the relevant features from the data.
#
# The best way to prevent your model from overfitting is using a dataset for training that covers the full range of inputs that the model is expected to handle. Additional data may only be useful if it covers new and interesting cases.
#
# However, sometimes you will need to use different regularization techniques to counteract the overfitting of the data. In this notebook we will explore some common techniques that can help you with this task.

# %% [markdown]
# #### At the end of the notebooks you should:
#
# * know different strategies to tackle overfitting
# * know how to apply L1 or L2 regularization
# * know what `dropout layers` are and how to use them

# %% [markdown]
# ## Setup

# %% [markdown]
# Before getting started, import the necessary packages:

# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras import regularizers


import pathlib
import shutil
import tempfile

print(tf.__version__)
# Out:
# 2.15.0

# %%
#!pip install -q git+https://github.com/tensorflow/docs

import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots

# %%
# Define seeds etc.
RSEED = 42
tf.keras.backend.set_floatx('float64')
plt.rcParams['figure.figsize'] = (15, 10)

# %% [markdown]
# ## The Boston Housing data set
#
# We will use the boston housing data set in this notebook. You can find it in the data folder in this repo.
#
# In the next few cells we:
# - load the CSV into a pandas DataFrame and peek at its shape/columns,
# - check for missing values so we know whether imputation is needed,
# - pull the target column (median house value) out of the feature frame,
# - create a train/test split to keep truly unseen data,
# - fit a `StandardScaler` only on the training features and apply it to both splits to avoid leakage,
# - convert the scaled features and target to NumPy arrays Keras expects.
#
# Keeping the preprocessing deterministic (seeded split + scaler fit on train only) makes the downstream model comparisons fair.

# %%
# Load data from data folder
df = pd.read_csv('../data/boston.csv')
df.head(3)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
#
#    PTRATIO  LSTAT  MEDV
# 0     15.3   4.98  24.0
# 1     17.8   9.14  21.6
# 2     17.8   4.03  34.7

# %%
# Shape of dataframe
df.shape
# Out:
# (506, 13)

# %%
# Check for missings
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
# Define target and remove from df 
target = df.pop("MEDV")

# %%
# Split into train and test set
X_train, X_test, y_train, y_test = train_test_split(df, target, random_state=RSEED)

# %%
# Scale numerical values
col_scale = ['CRIM', 'ZN', 'INDUS', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'LSTAT']

scaler = StandardScaler()
X_train[col_scale] = scaler.fit_transform(X_train[col_scale])
X_test[col_scale] = scaler.transform(X_test[col_scale])

# %%
# Convert to np array
X_train = X_train.values
X_test = X_test.values
y_train = y_train.values
y_test = y_test.values

# %% [markdown]
# ## Model Complexity
#
# One way to counteract under- or overfitting without using any regularization technique is to adapt the model complexity. The larger your neural network is the easier it is to overfit the data.
#
# Unfortunately, there is no magical formula to determine the right size or architecture of your model (in terms of the number of layers, or the right size for each layer). You will have to experiment using a series of different architectures.
# To find an appropriate model size, it's best to start with relatively few layers and parameters, then begin increasing the size of the layers or adding new layers until the validation loss gets worse.
#
# In this notebook we will train three different models with varying complexity on the Boston housing data set and compare their performance. The results will be stored in a dictionary and the following plotting functions will help us to visualize the performance.
# We will also define the optimizer we want to use as well as a [learning rate decay](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/schedules/InverseTimeDecay). Many models train better with a gradually decreasing learning rate during training.
# The `optimizers.schedule` helps us to reduce the learning rate over time:
#
# We'll also collect every training run in a `training_history` dictionary. Each entry stores the `History` object returned by `model.fit`, which holds the per-epoch `loss` and `mean_squared_error` for both train and validation sets. The helper plotting functions below simply read those logs, so as long as the key names stay consistent you can drop new model variants in and get comparable charts automatically.

# %%
# Define dictionary to store results
training_history = {}

# Define number of epochs and learning rate decay
N_TRAIN = len(X_train)
EPOCHS = 2000
BATCH_SIZE = 32
STEPS_PER_EPOCH = N_TRAIN // BATCH_SIZE
lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
    0.01,
    decay_steps=STEPS_PER_EPOCH*1000,
    decay_rate=1,
    staircase=False)


# Define optimizer used for modelling
optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=lr_schedule, name='Adam')

# %%
# Plotting function for MSE
def plot_metric(history):
    plt.plot(history.history['mse'])
    plt.plot(history.history['val_mse'])
    plt.title('Model MSE')
    plt.ylabel('MSE')
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.show()

# %%
# Plotting function for loss
def plot_loss(history):
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.title('Model Loss')
    plt.ylim([0, 10])
    plt.xlabel('Epoch')
    plt.ylabel('Error')
    plt.legend()
    plt.grid(True)

# %% [markdown]
# ### Small model
#
# We'll start with a rather small model with two hidden layers and 32 units.
#
# The following function contains our models architecture (the number of layers and units) as well as information about the optimizer, loss and metric we use.
#
# When you call `small_model.fit(...)`, watch how quickly the validation curves flatten. If both train and validation MSE stay high the network is underfitting; if training MSE keeps dropping while validation MSE bottoms out and rises, you're entering the overfitting regime. This baseline run gives us a reference point for the larger architectures.

# %%
# Define model architecture in function
def get_compiled_small_model():
    small_model = tf.keras.Sequential([
      tf.keras.layers.Dense(32,kernel_initializer = 'uniform', activation='relu', input_dim = 12),
      tf.keras.layers.Dense(32,kernel_initializer = 'uniform', activation='relu'),
      tf.keras.layers.Dense(1,kernel_initializer = 'uniform')
    ])

    small_model.compile(optimizer=optimizer,
                  loss='mae',
                  metrics=['mse'])
    return small_model

# %%
# Instantiate small model and print model summary
with tf.device('/cpu:0'):
    small_model = get_compiled_small_model()
    print(small_model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                416
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1505 (11.76 KB)
# Trainable params: 1505 (11.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 2026-02-05 18:38:33.850547: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Pro
# 2026-02-05 18:38:33.850757: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 32.00 GB
# 2026-02-05 18:38:33.850780: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 10.67 GB
# 2026-02-05 18:38:33.850830: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-02-05 18:38:33.850862: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
with tf.device('/cpu:0'):
    training_history['small'] = small_model.fit(X_train,
                        y_train,
                        validation_split=0.2,
                        verbose=1,
                        steps_per_epoch=STEPS_PER_EPOCH,
                        epochs=EPOCHS)
# Out:
# Epoch 1/2000
# 11/11 [==============================] - 0s 9ms/step - loss: 21.6499 - mse: 570.3690 - val_loss: 17.0042 - val_mse: 380.2405
# Epoch 2/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 14.1555 - mse: 276.8433 - val_loss: 8.9267 - val_mse: 113.3198
# Epoch 3/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 7.6908 - mse: 93.7303 - val_loss: 5.8808 - val_mse: 66.4983
# Epoch 4/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 4.8115 - mse: 38.7717 - val_loss: 3.8260 - val_mse: 31.5590
# Epoch 5/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 3.7967 - mse: 26.6306 - val_loss: 3.7724 - val_mse: 32.6001
# Epoch 6/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 3.5661 - mse: 24.1800 - val_loss: 3.6090 - val_mse: 31.3377
# Epoch 7/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 3.4057 - mse: 22.8240 - val_loss: 3.7345 - val_mse: 34.0611
# Epoch 8/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 3.2077 - mse: 22.8276 - val_loss: 4.0970 - val_mse: 38.3475
# Epoch 9/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 3.5255 - mse: 24.5742 - val_loss: 3.3021 - val_mse: 26.5680
# Epoch 10/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 3.3208 - mse: 22.0730 - val_loss: 3.3688 - val_mse: 27.9811
# Epoch 11/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 3.2565 - mse: 21.2101 - val_loss: 3.4393 - val_mse: 25.0283
# Epoch 12/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 3.1576 - mse: 20.9465 - val_loss: 4.0986 - val_mse: 32.6095
# Epoch 13/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 3.3003 - mse: 21.7929 - val_loss: 3.4453 - val_mse: 28.5829
# Epoch 14/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 3.0353 - mse: 20.3046 - val_loss: 3.2876 - val_mse: 26.3117
# Epoch 15/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 3.0598 - mse: 21.2092 - val_loss: 3.8364 - val_mse: 33.6997
# Epoch 16/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 3.0122 - mse: 20.3987 - val_loss: 3.1460 - val_mse: 24.9272
# Epoch 17/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.8010 - mse: 17.1064 - val_loss: 3.5113 - val_mse: 30.0155
# Epoch 18/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.9819 - mse: 20.1890 - val_loss: 3.3187 - val_mse: 28.6951
# Epoch 19/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.7116 - mse: 17.2199 - val_loss: 2.8873 - val_mse: 23.6846
# Epoch 20/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.7849 - mse: 17.5303 - val_loss: 3.1156 - val_mse: 26.4685
# Epoch 21/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.7051 - mse: 16.7390 - val_loss: 2.9693 - val_mse: 24.7398
# Epoch 22/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.5555 - mse: 15.6200 - val_loss: 2.7329 - val_mse: 20.5006
# Epoch 23/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.6274 - mse: 16.0447 - val_loss: 2.9340 - val_mse: 22.9803
# Epoch 24/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.5701 - mse: 16.6616 - val_loss: 3.4140 - val_mse: 26.5119
# Epoch 25/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.8061 - mse: 17.4185 - val_loss: 3.1627 - val_mse: 20.7914
# Epoch 26/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.6101 - mse: 15.0516 - val_loss: 2.9077 - val_mse: 21.0208
# Epoch 27/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.4039 - mse: 13.9493 - val_loss: 2.9378 - val_mse: 22.5365
# Epoch 28/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.5294 - mse: 15.3805 - val_loss: 2.9302 - val_mse: 21.9633
# Epoch 29/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.4111 - mse: 14.0666 - val_loss: 3.2713 - val_mse: 24.8438
# Epoch 30/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.6470 - mse: 15.9611 - val_loss: 2.6462 - val_mse: 19.3011
# Epoch 31/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.6065 - mse: 14.4407 - val_loss: 2.8758 - val_mse: 20.7318
# Epoch 32/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.4454 - mse: 13.4801 - val_loss: 2.8378 - val_mse: 21.3909
# Epoch 33/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.3982 - mse: 14.0152 - val_loss: 2.8257 - val_mse: 19.1782
# Epoch 34/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.2947 - mse: 12.8959 - val_loss: 2.6551 - val_mse: 18.4559
# Epoch 35/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.3375 - mse: 12.8965 - val_loss: 2.7931 - val_mse: 19.8045
# Epoch 36/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.3326 - mse: 12.3739 - val_loss: 2.7500 - val_mse: 20.3765
# Epoch 37/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.3125 - mse: 12.5896 - val_loss: 2.6117 - val_mse: 17.0733
# Epoch 38/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.2162 - mse: 12.1248 - val_loss: 2.9316 - val_mse: 19.3924
# Epoch 39/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.3801 - mse: 13.1951 - val_loss: 2.9038 - val_mse: 18.9726
# Epoch 40/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.5251 - mse: 14.1595 - val_loss: 3.2988 - val_mse: 22.2262
# Epoch 41/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.5424 - mse: 14.0601 - val_loss: 3.1052 - val_mse: 18.5627
# Epoch 42/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.8176 - mse: 15.4672 - val_loss: 3.9839 - val_mse: 27.9022
# Epoch 43/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 3.1233 - mse: 18.1537 - val_loss: 2.7862 - val_mse: 16.4143
# Epoch 44/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.5573 - mse: 13.8341 - val_loss: 2.7026 - val_mse: 16.3704
# Epoch 45/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.4833 - mse: 13.9936 - val_loss: 2.9659 - val_mse: 19.8124
# Epoch 46/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.2745 - mse: 11.7743 - val_loss: 2.6631 - val_mse: 17.7351
# Epoch 47/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.2918 - mse: 11.6499 - val_loss: 2.6958 - val_mse: 16.5854
# Epoch 48/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1434 - mse: 10.6848 - val_loss: 2.8801 - val_mse: 18.2300
# Epoch 49/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.2021 - mse: 11.4959 - val_loss: 2.8041 - val_mse: 17.2118
# Epoch 50/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1621 - mse: 10.9822 - val_loss: 2.8038 - val_mse: 16.7853
# Epoch 51/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.2011 - mse: 10.9298 - val_loss: 3.0071 - val_mse: 19.1703
# Epoch 52/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.3055 - mse: 11.2579 - val_loss: 2.8659 - val_mse: 17.5594
# Epoch 53/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.2111 - mse: 11.6916 - val_loss: 2.7149 - val_mse: 16.2407
# Epoch 54/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1925 - mse: 11.7170 - val_loss: 3.2356 - val_mse: 21.2366
# Epoch 55/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.3647 - mse: 11.9424 - val_loss: 2.8912 - val_mse: 18.0686
# Epoch 56/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.3706 - mse: 12.7855 - val_loss: 2.8178 - val_mse: 16.4420
# Epoch 57/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.2559 - mse: 11.1951 - val_loss: 2.6553 - val_mse: 15.6748
# Epoch 58/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1777 - mse: 10.9714 - val_loss: 2.7856 - val_mse: 19.1477
# Epoch 59/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1373 - mse: 11.1472 - val_loss: 2.6288 - val_mse: 15.7289
# Epoch 60/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1567 - mse: 11.0842 - val_loss: 2.9628 - val_mse: 17.3757
# Epoch 61/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.2552 - mse: 11.8176 - val_loss: 2.9753 - val_mse: 18.5141
# Epoch 62/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.2559 - mse: 11.4675 - val_loss: 2.5439 - val_mse: 15.4806
# Epoch 63/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1803 - mse: 11.3323 - val_loss: 2.7014 - val_mse: 16.6416
# Epoch 64/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0556 - mse: 10.2061 - val_loss: 2.6090 - val_mse: 16.0153
# Epoch 65/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0944 - mse: 10.4198 - val_loss: 2.7674 - val_mse: 18.5164
# Epoch 66/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1346 - mse: 10.2744 - val_loss: 2.7355 - val_mse: 17.9277
# Epoch 67/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1407 - mse: 10.5032 - val_loss: 2.5821 - val_mse: 15.9655
# Epoch 68/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.2083 - mse: 10.5746 - val_loss: 2.6738 - val_mse: 17.5413
# Epoch 69/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1772 - mse: 10.6161 - val_loss: 2.6824 - val_mse: 17.8909
# Epoch 70/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1474 - mse: 11.0258 - val_loss: 2.7698 - val_mse: 18.5886
# Epoch 71/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1524 - mse: 9.9333 - val_loss: 2.6351 - val_mse: 16.9649
# Epoch 72/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.2181 - mse: 10.9793 - val_loss: 2.5461 - val_mse: 14.7273
# Epoch 73/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1301 - mse: 10.2989 - val_loss: 2.5212 - val_mse: 15.6268
# Epoch 74/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1029 - mse: 10.0140 - val_loss: 2.7336 - val_mse: 16.9819
# Epoch 75/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0651 - mse: 9.5687 - val_loss: 2.6603 - val_mse: 16.5084
# Epoch 76/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0771 - mse: 9.8868 - val_loss: 2.5487 - val_mse: 16.6885
# Epoch 77/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1777 - mse: 10.9842 - val_loss: 2.5499 - val_mse: 16.1050
# Epoch 78/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1424 - mse: 10.2919 - val_loss: 2.6177 - val_mse: 15.8233
# Epoch 79/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0576 - mse: 9.7972 - val_loss: 2.6492 - val_mse: 15.8824
# Epoch 80/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1360 - mse: 10.2205 - val_loss: 2.6757 - val_mse: 16.7285
# Epoch 81/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9884 - mse: 9.2664 - val_loss: 2.6211 - val_mse: 15.7409
# Epoch 82/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0148 - mse: 9.4948 - val_loss: 2.6311 - val_mse: 15.0241
# Epoch 83/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0124 - mse: 9.3483 - val_loss: 2.5435 - val_mse: 14.9979
# Epoch 84/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9789 - mse: 9.2036 - val_loss: 2.8159 - val_mse: 16.5520
# Epoch 85/2000
# 11/11 [==============================] - 0s 4ms/step - loss: 2.1477 - mse: 10.1631 - val_loss: 3.0368 - val_mse: 18.1320
# Epoch 86/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.2704 - mse: 10.5510 - val_loss: 2.7062 - val_mse: 15.3043
# Epoch 87/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0435 - mse: 9.5408 - val_loss: 2.5525 - val_mse: 15.4366
# Epoch 88/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1488 - mse: 10.4882 - val_loss: 2.5455 - val_mse: 15.8141
# Epoch 89/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1571 - mse: 9.8509 - val_loss: 2.8444 - val_mse: 18.5489
# Epoch 90/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1519 - mse: 9.9821 - val_loss: 2.5880 - val_mse: 14.4201
# Epoch 91/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1331 - mse: 9.8328 - val_loss: 2.5764 - val_mse: 16.2009
# Epoch 92/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0004 - mse: 9.1052 - val_loss: 2.7325 - val_mse: 16.5028
# Epoch 93/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0579 - mse: 9.6657 - val_loss: 3.0613 - val_mse: 17.1524
# Epoch 94/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.2767 - mse: 10.6099 - val_loss: 2.5944 - val_mse: 15.2553
# Epoch 95/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1696 - mse: 9.6354 - val_loss: 2.7065 - val_mse: 17.3117
# Epoch 96/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0654 - mse: 9.5722 - val_loss: 2.6696 - val_mse: 16.0781
# Epoch 97/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9598 - mse: 9.0031 - val_loss: 2.7362 - val_mse: 16.2466
# Epoch 98/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9690 - mse: 8.9250 - val_loss: 2.8011 - val_mse: 15.8820
# Epoch 99/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9932 - mse: 8.9616 - val_loss: 2.8232 - val_mse: 16.8620
# Epoch 100/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9725 - mse: 8.9706 - val_loss: 2.7907 - val_mse: 15.7262
# Epoch 101/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1182 - mse: 9.4639 - val_loss: 2.7254 - val_mse: 15.1943
# Epoch 102/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9802 - mse: 8.4725 - val_loss: 2.6711 - val_mse: 15.9118
# Epoch 103/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9723 - mse: 8.9206 - val_loss: 2.8243 - val_mse: 15.8166
# Epoch 104/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0136 - mse: 9.2407 - val_loss: 2.8139 - val_mse: 15.3910
# Epoch 105/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0528 - mse: 8.9284 - val_loss: 2.6130 - val_mse: 15.9094
# Epoch 106/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1430 - mse: 9.3054 - val_loss: 2.5382 - val_mse: 15.2095
# Epoch 107/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1717 - mse: 10.3703 - val_loss: 2.6938 - val_mse: 16.3453
# Epoch 108/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1046 - mse: 9.6453 - val_loss: 2.6405 - val_mse: 16.1956
# Epoch 109/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0130 - mse: 9.1930 - val_loss: 2.9908 - val_mse: 17.6377
# Epoch 110/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0390 - mse: 9.6343 - val_loss: 2.8406 - val_mse: 16.2388
# Epoch 111/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.2913 - mse: 10.2574 - val_loss: 2.7492 - val_mse: 15.8122
# Epoch 112/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0701 - mse: 9.2423 - val_loss: 2.5486 - val_mse: 14.8404
# Epoch 113/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9866 - mse: 9.2441 - val_loss: 2.6409 - val_mse: 14.8594
# Epoch 114/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9265 - mse: 8.5330 - val_loss: 2.6286 - val_mse: 15.0752
# Epoch 115/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0804 - mse: 9.5540 - val_loss: 2.6153 - val_mse: 16.0034
# Epoch 116/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0579 - mse: 9.5952 - val_loss: 2.5205 - val_mse: 14.7449
# Epoch 117/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0768 - mse: 9.9097 - val_loss: 2.8807 - val_mse: 19.7792
# Epoch 118/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1388 - mse: 9.8954 - val_loss: 2.5211 - val_mse: 15.4100
# Epoch 119/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9781 - mse: 9.0878 - val_loss: 2.4871 - val_mse: 14.1328
# Epoch 120/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9217 - mse: 8.2759 - val_loss: 2.6323 - val_mse: 16.3276
# Epoch 121/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9101 - mse: 8.7236 - val_loss: 2.6168 - val_mse: 14.3780
# Epoch 122/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9642 - mse: 8.6093 - val_loss: 3.0379 - val_mse: 17.8950
# Epoch 123/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0420 - mse: 9.1475 - val_loss: 2.7975 - val_mse: 15.9830
# Epoch 124/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9421 - mse: 8.4287 - val_loss: 2.7273 - val_mse: 15.7762
# Epoch 125/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9589 - mse: 8.7701 - val_loss: 2.8995 - val_mse: 16.2173
# Epoch 126/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9039 - mse: 8.3241 - val_loss: 2.6256 - val_mse: 14.9168
# Epoch 127/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9298 - mse: 8.6200 - val_loss: 2.7520 - val_mse: 16.2330
# Epoch 128/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9264 - mse: 8.3769 - val_loss: 2.7198 - val_mse: 16.7142
# Epoch 129/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0704 - mse: 9.6148 - val_loss: 2.5866 - val_mse: 14.7869
# Epoch 130/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1163 - mse: 9.4006 - val_loss: 2.7341 - val_mse: 15.3478
# Epoch 131/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.2125 - mse: 10.0934 - val_loss: 3.0395 - val_mse: 17.2677
# Epoch 132/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0305 - mse: 9.0610 - val_loss: 2.9999 - val_mse: 15.8816
# Epoch 133/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1295 - mse: 9.4312 - val_loss: 2.9229 - val_mse: 16.5640
# Epoch 134/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.2747 - mse: 10.1084 - val_loss: 3.3790 - val_mse: 19.7145
# Epoch 135/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0557 - mse: 9.0735 - val_loss: 2.9210 - val_mse: 16.1542
# Epoch 136/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0536 - mse: 9.2354 - val_loss: 3.3141 - val_mse: 19.1738
# Epoch 137/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.2751 - mse: 10.5199 - val_loss: 3.0558 - val_mse: 17.9732
# Epoch 138/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9391 - mse: 8.1938 - val_loss: 2.8634 - val_mse: 14.9298
# Epoch 139/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0547 - mse: 8.4734 - val_loss: 3.0053 - val_mse: 17.3800
# Epoch 140/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9625 - mse: 8.1416 - val_loss: 2.7615 - val_mse: 14.2572
# Epoch 141/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9224 - mse: 8.3565 - val_loss: 2.6590 - val_mse: 15.0679
# Epoch 142/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9316 - mse: 8.1865 - val_loss: 2.6959 - val_mse: 14.7649
# Epoch 143/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0389 - mse: 8.7677 - val_loss: 3.0657 - val_mse: 17.5701
# Epoch 144/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1177 - mse: 9.4738 - val_loss: 2.6888 - val_mse: 15.4644
# Epoch 145/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9456 - mse: 8.4103 - val_loss: 2.4667 - val_mse: 14.7662
# Epoch 146/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9398 - mse: 8.7938 - val_loss: 2.6930 - val_mse: 16.0895
# Epoch 147/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9979 - mse: 8.3385 - val_loss: 2.6877 - val_mse: 17.9411
# Epoch 148/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9973 - mse: 8.8466 - val_loss: 2.5997 - val_mse: 15.3573
# Epoch 149/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9393 - mse: 8.9082 - val_loss: 2.8443 - val_mse: 16.4134
# Epoch 150/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8840 - mse: 8.3298 - val_loss: 2.6901 - val_mse: 14.8254
# Epoch 151/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9054 - mse: 8.2247 - val_loss: 2.6572 - val_mse: 15.0579
# Epoch 152/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9653 - mse: 8.7227 - val_loss: 2.6263 - val_mse: 15.2906
# Epoch 153/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1162 - mse: 9.7784 - val_loss: 2.9045 - val_mse: 18.6185
# Epoch 154/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0930 - mse: 9.8431 - val_loss: 2.8702 - val_mse: 15.1693
# Epoch 155/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9241 - mse: 7.5041 - val_loss: 2.7561 - val_mse: 16.8867
# Epoch 156/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9534 - mse: 8.2134 - val_loss: 2.6904 - val_mse: 14.3637
# Epoch 157/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0099 - mse: 8.9341 - val_loss: 2.8983 - val_mse: 16.2351
# Epoch 158/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8488 - mse: 7.7646 - val_loss: 2.6591 - val_mse: 14.6783
# Epoch 159/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9346 - mse: 8.7468 - val_loss: 2.7445 - val_mse: 16.3095
# Epoch 160/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0400 - mse: 8.7216 - val_loss: 2.6810 - val_mse: 15.2303
# Epoch 161/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9279 - mse: 8.2158 - val_loss: 2.7554 - val_mse: 15.7116
# Epoch 162/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8543 - mse: 8.0152 - val_loss: 2.8022 - val_mse: 15.1192
# Epoch 163/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9252 - mse: 8.0955 - val_loss: 2.8251 - val_mse: 15.9212
# Epoch 164/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9000 - mse: 8.2525 - val_loss: 2.5944 - val_mse: 14.3570
# Epoch 165/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8849 - mse: 8.0449 - val_loss: 2.8304 - val_mse: 15.5542
# Epoch 166/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1268 - mse: 9.9023 - val_loss: 2.8414 - val_mse: 16.4253
# Epoch 167/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0726 - mse: 8.7898 - val_loss: 3.3365 - val_mse: 19.3035
# Epoch 168/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0935 - mse: 8.7063 - val_loss: 3.1091 - val_mse: 17.5736
# Epoch 169/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1663 - mse: 9.7598 - val_loss: 3.1970 - val_mse: 19.0629
# Epoch 170/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1057 - mse: 8.6745 - val_loss: 3.7191 - val_mse: 24.3853
# Epoch 171/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.2502 - mse: 10.6978 - val_loss: 2.9928 - val_mse: 16.0740
# Epoch 172/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0505 - mse: 9.2993 - val_loss: 2.9195 - val_mse: 17.6505
# Epoch 173/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9436 - mse: 8.5632 - val_loss: 2.6985 - val_mse: 14.7922
# Epoch 174/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9178 - mse: 8.0486 - val_loss: 2.8358 - val_mse: 16.2514
# Epoch 175/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8206 - mse: 7.7817 - val_loss: 2.5988 - val_mse: 14.6098
# Epoch 176/2000
# 11/11 [==============================] - 0s 4ms/step - loss: 1.7951 - mse: 7.4520 - val_loss: 2.6749 - val_mse: 14.2507
# Epoch 177/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8680 - mse: 8.0345 - val_loss: 2.7053 - val_mse: 15.6101
# Epoch 178/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8458 - mse: 8.0675 - val_loss: 2.8133 - val_mse: 15.6078
# Epoch 179/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9178 - mse: 8.1205 - val_loss: 2.6727 - val_mse: 14.7540
# Epoch 180/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9540 - mse: 8.2806 - val_loss: 2.7230 - val_mse: 15.4993
# Epoch 181/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9110 - mse: 8.3514 - val_loss: 2.4635 - val_mse: 13.3012
# Epoch 182/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8400 - mse: 7.4053 - val_loss: 2.8784 - val_mse: 16.8305
# Epoch 183/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8958 - mse: 7.9513 - val_loss: 2.8063 - val_mse: 15.7116
# Epoch 184/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8874 - mse: 7.9147 - val_loss: 2.5683 - val_mse: 14.1271
# Epoch 185/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7978 - mse: 7.8114 - val_loss: 2.8562 - val_mse: 15.8043
# Epoch 186/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8097 - mse: 7.6614 - val_loss: 2.6950 - val_mse: 15.1032
# Epoch 187/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8528 - mse: 8.1084 - val_loss: 2.6723 - val_mse: 16.8052
# Epoch 188/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9262 - mse: 8.0588 - val_loss: 2.5423 - val_mse: 14.7959
# Epoch 189/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9159 - mse: 8.5618 - val_loss: 2.6082 - val_mse: 14.7408
# Epoch 190/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8666 - mse: 8.0765 - val_loss: 2.5849 - val_mse: 15.0575
# Epoch 191/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8807 - mse: 8.0214 - val_loss: 2.8561 - val_mse: 15.4483
# Epoch 192/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9334 - mse: 8.2080 - val_loss: 2.7334 - val_mse: 15.3316
# Epoch 193/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8618 - mse: 7.9048 - val_loss: 2.7598 - val_mse: 15.1184
# Epoch 194/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8608 - mse: 8.0089 - val_loss: 2.8247 - val_mse: 16.0841
# Epoch 195/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8149 - mse: 7.7307 - val_loss: 2.8555 - val_mse: 15.6919
# Epoch 196/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8856 - mse: 7.8247 - val_loss: 2.8982 - val_mse: 16.7814
# Epoch 197/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8809 - mse: 7.8529 - val_loss: 2.9398 - val_mse: 15.9565
# Epoch 198/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8741 - mse: 7.8318 - val_loss: 2.7382 - val_mse: 15.0790
# Epoch 199/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8283 - mse: 7.6513 - val_loss: 2.7015 - val_mse: 15.1095
# Epoch 200/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8137 - mse: 7.8902 - val_loss: 2.7297 - val_mse: 14.9675
# Epoch 201/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9326 - mse: 8.0150 - val_loss: 2.7899 - val_mse: 14.7734
# Epoch 202/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8799 - mse: 7.6175 - val_loss: 2.7448 - val_mse: 15.5404
# Epoch 203/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0148 - mse: 8.5324 - val_loss: 2.5228 - val_mse: 15.0376
# Epoch 204/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9347 - mse: 8.4368 - val_loss: 2.6557 - val_mse: 15.3199
# Epoch 205/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7883 - mse: 7.2815 - val_loss: 2.6560 - val_mse: 15.5827
# Epoch 206/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9121 - mse: 8.3863 - val_loss: 2.6243 - val_mse: 15.1886
# Epoch 207/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8662 - mse: 7.7607 - val_loss: 2.5442 - val_mse: 14.7384
# Epoch 208/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8552 - mse: 7.7649 - val_loss: 2.7180 - val_mse: 15.2742
# Epoch 209/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8489 - mse: 8.0600 - val_loss: 2.6032 - val_mse: 14.9084
# Epoch 210/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9107 - mse: 8.3070 - val_loss: 2.7989 - val_mse: 16.1334
# Epoch 211/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8094 - mse: 7.5094 - val_loss: 2.5192 - val_mse: 14.5424
# Epoch 212/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8554 - mse: 7.9576 - val_loss: 2.7495 - val_mse: 15.3116
# Epoch 213/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9169 - mse: 8.4949 - val_loss: 3.1845 - val_mse: 19.4121
# Epoch 214/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9276 - mse: 8.4501 - val_loss: 2.6418 - val_mse: 14.1349
# Epoch 215/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7922 - mse: 7.5545 - val_loss: 2.6975 - val_mse: 15.8733
# Epoch 216/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8987 - mse: 8.0654 - val_loss: 2.6665 - val_mse: 14.3167
# Epoch 217/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8429 - mse: 7.8882 - val_loss: 2.8100 - val_mse: 15.2985
# Epoch 218/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8846 - mse: 7.6520 - val_loss: 3.0142 - val_mse: 17.0774
# Epoch 219/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0054 - mse: 8.4380 - val_loss: 2.9102 - val_mse: 16.5391
# Epoch 220/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8458 - mse: 7.5746 - val_loss: 2.6336 - val_mse: 14.4244
# Epoch 221/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7924 - mse: 7.6149 - val_loss: 2.6253 - val_mse: 14.7768
# Epoch 222/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8232 - mse: 7.6260 - val_loss: 2.7819 - val_mse: 15.2371
# Epoch 223/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9247 - mse: 8.0017 - val_loss: 2.8322 - val_mse: 15.4734
# Epoch 224/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9127 - mse: 7.6441 - val_loss: 2.8809 - val_mse: 15.0493
# Epoch 225/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9698 - mse: 8.1564 - val_loss: 2.7483 - val_mse: 15.1236
# Epoch 226/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8854 - mse: 7.8213 - val_loss: 2.9005 - val_mse: 15.3039
# Epoch 227/2000
# 11/11 [==============================] - 0s 3ms/step - loss: 1.8140 - mse: 7.4634 - val_loss: 3.0888 - val_mse: 18.3862
# Epoch 228/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8800 - mse: 7.9471 - val_loss: 2.5327 - val_mse: 13.7297
# Epoch 229/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7913 - mse: 7.5069 - val_loss: 2.9202 - val_mse: 15.7265
# Epoch 230/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7833 - mse: 7.3222 - val_loss: 2.7985 - val_mse: 15.7926
# Epoch 231/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9468 - mse: 8.0814 - val_loss: 2.8668 - val_mse: 15.7928
# Epoch 232/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8954 - mse: 7.5888 - val_loss: 2.7696 - val_mse: 15.3273
# Epoch 233/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9549 - mse: 8.2107 - val_loss: 2.5974 - val_mse: 13.7626
# Epoch 234/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0431 - mse: 8.5670 - val_loss: 2.5510 - val_mse: 14.7818
# Epoch 235/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8240 - mse: 7.3458 - val_loss: 2.8106 - val_mse: 17.3027
# Epoch 236/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9272 - mse: 8.0595 - val_loss: 2.3979 - val_mse: 13.5333
# Epoch 237/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8463 - mse: 7.6147 - val_loss: 2.7809 - val_mse: 15.9294
# Epoch 238/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8720 - mse: 7.6180 - val_loss: 2.7773 - val_mse: 14.9865
# Epoch 239/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8499 - mse: 7.7364 - val_loss: 2.6777 - val_mse: 14.9306
# Epoch 240/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7974 - mse: 7.7328 - val_loss: 2.6315 - val_mse: 14.3549
# Epoch 241/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7312 - mse: 7.2200 - val_loss: 2.9630 - val_mse: 16.4297
# Epoch 242/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8534 - mse: 7.9729 - val_loss: 2.7023 - val_mse: 15.2464
# Epoch 243/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8182 - mse: 7.3742 - val_loss: 2.7315 - val_mse: 14.7434
# Epoch 244/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7608 - mse: 6.9581 - val_loss: 2.7508 - val_mse: 17.1508
# Epoch 245/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8030 - mse: 7.5601 - val_loss: 2.5967 - val_mse: 14.5199
# Epoch 246/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9164 - mse: 7.6241 - val_loss: 2.6254 - val_mse: 14.7878
# Epoch 247/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9070 - mse: 7.8662 - val_loss: 2.8878 - val_mse: 15.5418
# Epoch 248/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9295 - mse: 7.8472 - val_loss: 3.3182 - val_mse: 20.3409
# Epoch 249/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1893 - mse: 9.3540 - val_loss: 2.9608 - val_mse: 16.4011
# Epoch 250/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8473 - mse: 7.2323 - val_loss: 2.6928 - val_mse: 14.9831
# Epoch 251/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7890 - mse: 7.6048 - val_loss: 2.7224 - val_mse: 15.6090
# Epoch 252/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7669 - mse: 7.3391 - val_loss: 2.6469 - val_mse: 15.3531
# Epoch 253/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7455 - mse: 7.3980 - val_loss: 2.6536 - val_mse: 14.6334
# Epoch 254/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8570 - mse: 7.3779 - val_loss: 3.0554 - val_mse: 17.5505
# Epoch 255/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9505 - mse: 8.3256 - val_loss: 2.9520 - val_mse: 15.8665
# Epoch 256/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9749 - mse: 8.3197 - val_loss: 2.9920 - val_mse: 16.0148
# Epoch 257/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8627 - mse: 7.4932 - val_loss: 2.7003 - val_mse: 14.3474
# Epoch 258/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7672 - mse: 7.2846 - val_loss: 2.7768 - val_mse: 15.1673
# Epoch 259/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8221 - mse: 7.9002 - val_loss: 2.6836 - val_mse: 14.8004
# Epoch 260/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7165 - mse: 7.1551 - val_loss: 2.5326 - val_mse: 14.6714
# Epoch 261/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7950 - mse: 7.4767 - val_loss: 2.5536 - val_mse: 14.2386
# Epoch 262/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8285 - mse: 7.2788 - val_loss: 2.8213 - val_mse: 16.0638
# Epoch 263/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7799 - mse: 7.3925 - val_loss: 2.6878 - val_mse: 15.4367
# Epoch 264/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7638 - mse: 7.2970 - val_loss: 2.4996 - val_mse: 14.3796
# Epoch 265/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7087 - mse: 6.9176 - val_loss: 2.5706 - val_mse: 14.4748
# Epoch 266/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7640 - mse: 7.1745 - val_loss: 2.5114 - val_mse: 14.5773
# Epoch 267/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7405 - mse: 7.1232 - val_loss: 2.4712 - val_mse: 14.0800
# Epoch 268/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6926 - mse: 6.8597 - val_loss: 2.6233 - val_mse: 14.8716
# Epoch 269/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7184 - mse: 7.2658 - val_loss: 2.4705 - val_mse: 15.1362
# Epoch 270/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7946 - mse: 7.4472 - val_loss: 2.6067 - val_mse: 15.0239
# Epoch 271/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7282 - mse: 7.2871 - val_loss: 2.5048 - val_mse: 14.1943
# Epoch 272/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7062 - mse: 6.9058 - val_loss: 2.4370 - val_mse: 13.8107
# Epoch 273/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7028 - mse: 7.0837 - val_loss: 2.8013 - val_mse: 15.0964
# Epoch 274/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8984 - mse: 7.5064 - val_loss: 2.7604 - val_mse: 15.2332
# Epoch 275/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7827 - mse: 7.2283 - val_loss: 2.7490 - val_mse: 14.3313
# Epoch 276/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8469 - mse: 7.5227 - val_loss: 2.6943 - val_mse: 14.9615
# Epoch 277/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7776 - mse: 7.2422 - val_loss: 2.5280 - val_mse: 13.9809
# Epoch 278/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7328 - mse: 7.1338 - val_loss: 2.8200 - val_mse: 15.6376
# Epoch 279/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7773 - mse: 7.3055 - val_loss: 2.6732 - val_mse: 14.9048
# Epoch 280/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6794 - mse: 6.8579 - val_loss: 2.4913 - val_mse: 14.0599
# Epoch 281/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7460 - mse: 7.0403 - val_loss: 2.6213 - val_mse: 15.5284
# Epoch 282/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7584 - mse: 7.5360 - val_loss: 2.7951 - val_mse: 15.3234
# Epoch 283/2000
# 11/11 [==============================] - 0s 4ms/step - loss: 1.7495 - mse: 7.0484 - val_loss: 2.6781 - val_mse: 14.1689
# Epoch 284/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7233 - mse: 6.9891 - val_loss: 2.5017 - val_mse: 13.7191
# Epoch 285/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7358 - mse: 6.9481 - val_loss: 2.6528 - val_mse: 14.8199
# Epoch 286/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6710 - mse: 6.7177 - val_loss: 2.4925 - val_mse: 13.5857
# Epoch 287/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6972 - mse: 6.9068 - val_loss: 2.5158 - val_mse: 14.3880
# Epoch 288/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6894 - mse: 6.9156 - val_loss: 2.4124 - val_mse: 13.7640
# Epoch 289/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7408 - mse: 7.0249 - val_loss: 2.5389 - val_mse: 14.5421
# Epoch 290/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7325 - mse: 7.0300 - val_loss: 2.7711 - val_mse: 15.5035
# Epoch 291/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8300 - mse: 7.7838 - val_loss: 2.6527 - val_mse: 14.7938
# Epoch 292/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7972 - mse: 7.1811 - val_loss: 2.3489 - val_mse: 13.3678
# Epoch 293/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6487 - mse: 6.6520 - val_loss: 2.5175 - val_mse: 14.7284
# Epoch 294/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6522 - mse: 6.4575 - val_loss: 2.4797 - val_mse: 13.7309
# Epoch 295/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6608 - mse: 6.5551 - val_loss: 2.5185 - val_mse: 14.3534
# Epoch 296/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7079 - mse: 7.2041 - val_loss: 2.3798 - val_mse: 13.6185
# Epoch 297/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6937 - mse: 6.6154 - val_loss: 2.6790 - val_mse: 15.5292
# Epoch 298/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7948 - mse: 7.1158 - val_loss: 2.4166 - val_mse: 13.1246
# Epoch 299/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7532 - mse: 7.2018 - val_loss: 2.5076 - val_mse: 14.1262
# Epoch 300/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6303 - mse: 6.8190 - val_loss: 2.5679 - val_mse: 14.6044
# Epoch 301/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6678 - mse: 6.6914 - val_loss: 2.5724 - val_mse: 14.6568
# Epoch 302/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7038 - mse: 6.8906 - val_loss: 2.4792 - val_mse: 14.7518
# Epoch 303/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6861 - mse: 6.6644 - val_loss: 2.6126 - val_mse: 14.9218
# Epoch 304/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7995 - mse: 7.4152 - val_loss: 2.9090 - val_mse: 15.6052
# Epoch 305/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9028 - mse: 7.6309 - val_loss: 2.7233 - val_mse: 15.3440
# Epoch 306/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7275 - mse: 7.2230 - val_loss: 2.4764 - val_mse: 14.6911
# Epoch 307/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6595 - mse: 6.4571 - val_loss: 2.4427 - val_mse: 14.6835
# Epoch 308/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7923 - mse: 7.3358 - val_loss: 2.3686 - val_mse: 13.8633
# Epoch 309/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6368 - mse: 6.5114 - val_loss: 2.4393 - val_mse: 14.5067
# Epoch 310/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9731 - mse: 8.1178 - val_loss: 2.4304 - val_mse: 14.6581
# Epoch 311/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8042 - mse: 6.9596 - val_loss: 2.4486 - val_mse: 14.7423
# Epoch 312/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7886 - mse: 7.6442 - val_loss: 2.5331 - val_mse: 15.0201
# Epoch 313/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7424 - mse: 7.0630 - val_loss: 2.5497 - val_mse: 14.0713
# Epoch 314/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7351 - mse: 6.4509 - val_loss: 2.9884 - val_mse: 16.9182
# Epoch 315/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9084 - mse: 7.5574 - val_loss: 2.5312 - val_mse: 13.5046
# Epoch 316/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6884 - mse: 6.4813 - val_loss: 2.3820 - val_mse: 13.5577
# Epoch 317/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6253 - mse: 6.5205 - val_loss: 2.4505 - val_mse: 13.6686
# Epoch 318/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6933 - mse: 6.7942 - val_loss: 2.4384 - val_mse: 14.6420
# Epoch 319/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6579 - mse: 6.4233 - val_loss: 2.4381 - val_mse: 14.5504
# Epoch 320/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8181 - mse: 7.2641 - val_loss: 2.3990 - val_mse: 14.7742
# Epoch 321/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6965 - mse: 6.6163 - val_loss: 2.4705 - val_mse: 14.4337
# Epoch 322/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6371 - mse: 6.5087 - val_loss: 2.4651 - val_mse: 13.9605
# Epoch 323/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5669 - mse: 6.1949 - val_loss: 2.5057 - val_mse: 14.7548
# Epoch 324/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6044 - mse: 6.4637 - val_loss: 2.4580 - val_mse: 13.8758
# Epoch 325/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6214 - mse: 6.3170 - val_loss: 2.7873 - val_mse: 15.3003
# Epoch 326/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7167 - mse: 6.4873 - val_loss: 2.5618 - val_mse: 14.0088
# Epoch 327/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5873 - mse: 6.2014 - val_loss: 2.4964 - val_mse: 14.1973
# Epoch 328/2000
# 11/11 [==============================] - 0s 3ms/step - loss: 1.6531 - mse: 6.1660 - val_loss: 2.6484 - val_mse: 14.8777
# Epoch 329/2000
# 11/11 [==============================] - 0s 3ms/step - loss: 1.7421 - mse: 7.1392 - val_loss: 2.6473 - val_mse: 14.4987
# Epoch 330/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5901 - mse: 6.0532 - val_loss: 2.4238 - val_mse: 14.1320
# Epoch 331/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6663 - mse: 6.9393 - val_loss: 2.5499 - val_mse: 14.9168
# Epoch 332/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6247 - mse: 6.0679 - val_loss: 2.4737 - val_mse: 14.3405
# Epoch 333/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6376 - mse: 6.5639 - val_loss: 2.4076 - val_mse: 13.9190
# Epoch 334/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6945 - mse: 6.6252 - val_loss: 2.5665 - val_mse: 14.3453
# Epoch 335/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6758 - mse: 6.7316 - val_loss: 2.5051 - val_mse: 14.1016
# Epoch 336/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7176 - mse: 6.3783 - val_loss: 2.5071 - val_mse: 14.4136
# Epoch 337/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6240 - mse: 6.3549 - val_loss: 2.4126 - val_mse: 14.0135
# Epoch 338/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6904 - mse: 6.3907 - val_loss: 2.4504 - val_mse: 14.9772
# Epoch 339/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8151 - mse: 6.7409 - val_loss: 2.4761 - val_mse: 15.3213
# Epoch 340/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8457 - mse: 6.7827 - val_loss: 2.5515 - val_mse: 16.1207
# Epoch 341/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7061 - mse: 6.5794 - val_loss: 2.4395 - val_mse: 14.6655
# Epoch 342/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7490 - mse: 7.3169 - val_loss: 2.3782 - val_mse: 13.4238
# Epoch 343/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6093 - mse: 5.7811 - val_loss: 2.4283 - val_mse: 14.4377
# Epoch 344/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6717 - mse: 6.2692 - val_loss: 2.3577 - val_mse: 14.1855
# Epoch 345/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7304 - mse: 7.0009 - val_loss: 2.4214 - val_mse: 14.0990
# Epoch 346/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6619 - mse: 6.5045 - val_loss: 2.4946 - val_mse: 14.6232
# Epoch 347/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5623 - mse: 5.9472 - val_loss: 2.3316 - val_mse: 13.4253
# Epoch 348/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7321 - mse: 6.6290 - val_loss: 2.4729 - val_mse: 15.1548
# Epoch 349/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7638 - mse: 6.9894 - val_loss: 2.5109 - val_mse: 14.3972
# Epoch 350/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7355 - mse: 6.4199 - val_loss: 2.5920 - val_mse: 15.0806
# Epoch 351/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7515 - mse: 6.4931 - val_loss: 2.5693 - val_mse: 14.1803
# Epoch 352/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7162 - mse: 6.7720 - val_loss: 2.5185 - val_mse: 13.5939
# Epoch 353/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6423 - mse: 6.0021 - val_loss: 2.5888 - val_mse: 16.3423
# Epoch 354/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7451 - mse: 7.2745 - val_loss: 2.4676 - val_mse: 14.6840
# Epoch 355/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7973 - mse: 7.0906 - val_loss: 2.4054 - val_mse: 14.0011
# Epoch 356/2000
# ...
# Epoch 1884/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7430 - mse: 1.9398 - val_loss: 2.4555 - val_mse: 10.2758
# Epoch 1885/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7390 - mse: 1.9428 - val_loss: 2.3868 - val_mse: 9.7149
# Epoch 1886/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.8277 - mse: 2.1434 - val_loss: 2.4376 - val_mse: 10.1249
# Epoch 1887/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.9283 - mse: 2.3012 - val_loss: 2.5298 - val_mse: 10.4160
# Epoch 1888/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.8345 - mse: 2.1513 - val_loss: 2.4651 - val_mse: 10.3991
# Epoch 1889/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7404 - mse: 1.9183 - val_loss: 2.4609 - val_mse: 9.8670
# Epoch 1890/2000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7113 - mse: 1.8927 - val_loss: 2.4375 - val_mse: 10.0650
# Epoch 1891/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7553 - mse: 1.9620 - val_loss: 2.4647 - val_mse: 10.2578
# Epoch 1892/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7397 - mse: 1.9325 - val_loss: 2.4291 - val_mse: 9.8982
# Epoch 1893/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7297 - mse: 2.0001 - val_loss: 2.5065 - val_mse: 10.5720
# Epoch 1894/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7582 - mse: 1.9833 - val_loss: 2.4731 - val_mse: 10.1421
# Epoch 1895/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7863 - mse: 2.0041 - val_loss: 2.4275 - val_mse: 10.3197
# Epoch 1896/2000
# 11/11 [==============================] - 0s 5ms/step - loss: 0.7424 - mse: 1.9777 - val_loss: 2.5217 - val_mse: 10.3177
# Epoch 1897/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7614 - mse: 1.9730 - val_loss: 2.5037 - val_mse: 10.8969
# Epoch 1898/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6988 - mse: 1.9349 - val_loss: 2.4525 - val_mse: 10.0628
# Epoch 1899/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7168 - mse: 1.9548 - val_loss: 2.5434 - val_mse: 10.8545
# Epoch 1900/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7230 - mse: 1.9436 - val_loss: 2.4832 - val_mse: 10.0691
# Epoch 1901/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6990 - mse: 1.8590 - val_loss: 2.4229 - val_mse: 9.9949
# Epoch 1902/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7786 - mse: 1.9962 - val_loss: 2.5171 - val_mse: 9.9529
# Epoch 1903/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.8677 - mse: 2.1394 - val_loss: 2.4880 - val_mse: 10.9647
# Epoch 1904/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.8372 - mse: 2.0860 - val_loss: 2.4270 - val_mse: 10.1101
# Epoch 1905/2000
# 11/11 [==============================] - 0s 5ms/step - loss: 0.9486 - mse: 2.2688 - val_loss: 2.4670 - val_mse: 9.9549
# Epoch 1906/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.8249 - mse: 2.0252 - val_loss: 2.4254 - val_mse: 10.2533
# Epoch 1907/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.8304 - mse: 2.1227 - val_loss: 2.4720 - val_mse: 10.0859
# Epoch 1908/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7329 - mse: 1.8592 - val_loss: 2.4894 - val_mse: 10.3172
# Epoch 1909/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.8066 - mse: 2.0731 - val_loss: 2.4766 - val_mse: 9.9594
# Epoch 1910/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.8160 - mse: 2.0789 - val_loss: 2.5346 - val_mse: 10.9473
# Epoch 1911/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7860 - mse: 1.9223 - val_loss: 2.4676 - val_mse: 9.8920
# Epoch 1912/2000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7678 - mse: 2.0338 - val_loss: 2.4699 - val_mse: 10.1563
# Epoch 1913/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6735 - mse: 1.8422 - val_loss: 2.3932 - val_mse: 9.4420
# Epoch 1914/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7676 - mse: 1.9512 - val_loss: 2.4719 - val_mse: 10.2882
# Epoch 1915/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7311 - mse: 1.9208 - val_loss: 2.3765 - val_mse: 10.0288
# Epoch 1916/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7586 - mse: 1.9080 - val_loss: 2.4959 - val_mse: 10.2080
# Epoch 1917/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7097 - mse: 1.9142 - val_loss: 2.4960 - val_mse: 10.0807
# Epoch 1918/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6896 - mse: 1.8598 - val_loss: 2.4874 - val_mse: 10.7261
# Epoch 1919/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7745 - mse: 1.9830 - val_loss: 2.3983 - val_mse: 9.5652
# Epoch 1920/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7643 - mse: 2.0218 - val_loss: 2.5006 - val_mse: 10.4147
# Epoch 1921/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7275 - mse: 1.9432 - val_loss: 2.4409 - val_mse: 9.9046
# Epoch 1922/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6898 - mse: 1.9225 - val_loss: 2.4815 - val_mse: 10.0576
# Epoch 1923/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7253 - mse: 1.9160 - val_loss: 2.4646 - val_mse: 10.3184
# Epoch 1924/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7946 - mse: 1.9719 - val_loss: 2.4803 - val_mse: 10.2150
# Epoch 1925/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7305 - mse: 1.8593 - val_loss: 2.4578 - val_mse: 10.2450
# Epoch 1926/2000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7475 - mse: 1.8890 - val_loss: 2.4861 - val_mse: 10.1867
# Epoch 1927/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.8270 - mse: 2.0859 - val_loss: 2.5236 - val_mse: 10.9080
# Epoch 1928/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7660 - mse: 1.9276 - val_loss: 2.4763 - val_mse: 10.3330
# Epoch 1929/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6956 - mse: 1.8449 - val_loss: 2.4837 - val_mse: 10.2013
# Epoch 1930/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7034 - mse: 1.9195 - val_loss: 2.4779 - val_mse: 9.8618
# Epoch 1931/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7299 - mse: 1.8502 - val_loss: 2.4385 - val_mse: 10.3912
# Epoch 1932/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7166 - mse: 1.8794 - val_loss: 2.5640 - val_mse: 10.5217
# Epoch 1933/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7522 - mse: 1.9526 - val_loss: 2.4288 - val_mse: 10.3476
# Epoch 1934/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7407 - mse: 1.9440 - val_loss: 2.5277 - val_mse: 10.5622
# Epoch 1935/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7498 - mse: 1.9342 - val_loss: 2.5030 - val_mse: 10.2848
# Epoch 1936/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7437 - mse: 2.0002 - val_loss: 2.4704 - val_mse: 10.3110
# Epoch 1937/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7210 - mse: 1.8844 - val_loss: 2.4869 - val_mse: 10.1656
# Epoch 1938/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6708 - mse: 1.8203 - val_loss: 2.4286 - val_mse: 9.9410
# Epoch 1939/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6870 - mse: 1.8158 - val_loss: 2.5022 - val_mse: 10.5097
# Epoch 1940/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6892 - mse: 1.8558 - val_loss: 2.4769 - val_mse: 10.1584
# Epoch 1941/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7187 - mse: 1.9001 - val_loss: 2.4502 - val_mse: 10.1918
# Epoch 1942/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7476 - mse: 1.9656 - val_loss: 2.3939 - val_mse: 9.6057
# Epoch 1943/2000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7084 - mse: 1.8390 - val_loss: 2.4648 - val_mse: 10.2213
# Epoch 1944/2000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7292 - mse: 1.8701 - val_loss: 2.4681 - val_mse: 10.1989
# Epoch 1945/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6842 - mse: 1.8151 - val_loss: 2.5001 - val_mse: 10.0297
# Epoch 1946/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7305 - mse: 1.9086 - val_loss: 2.4637 - val_mse: 10.2306
# Epoch 1947/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7310 - mse: 1.9127 - val_loss: 2.5656 - val_mse: 10.8550
# Epoch 1948/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7184 - mse: 1.9240 - val_loss: 2.4598 - val_mse: 10.0770
# Epoch 1949/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6969 - mse: 1.8586 - val_loss: 2.4617 - val_mse: 10.3443
# Epoch 1950/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6714 - mse: 1.8052 - val_loss: 2.4694 - val_mse: 9.8992
# Epoch 1951/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7158 - mse: 1.9125 - val_loss: 2.5560 - val_mse: 10.4397
# Epoch 1952/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7327 - mse: 1.9442 - val_loss: 2.4386 - val_mse: 9.8149
# Epoch 1953/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6895 - mse: 1.8882 - val_loss: 2.5026 - val_mse: 10.5943
# Epoch 1954/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7322 - mse: 1.9986 - val_loss: 2.5486 - val_mse: 10.5560
# Epoch 1955/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7688 - mse: 1.9855 - val_loss: 2.5245 - val_mse: 10.5533
# Epoch 1956/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7542 - mse: 1.9263 - val_loss: 2.4990 - val_mse: 10.5394
# Epoch 1957/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6709 - mse: 1.8630 - val_loss: 2.4944 - val_mse: 10.0692
# Epoch 1958/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6567 - mse: 1.7817 - val_loss: 2.5011 - val_mse: 10.3705
# Epoch 1959/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6576 - mse: 1.8276 - val_loss: 2.4744 - val_mse: 10.0315
# Epoch 1960/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6871 - mse: 1.8464 - val_loss: 2.5734 - val_mse: 10.9320
# Epoch 1961/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6627 - mse: 1.8014 - val_loss: 2.4629 - val_mse: 10.0738
# Epoch 1962/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7098 - mse: 1.8330 - val_loss: 2.5239 - val_mse: 10.2255
# Epoch 1963/2000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7266 - mse: 1.8826 - val_loss: 2.5378 - val_mse: 10.7911
# Epoch 1964/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7565 - mse: 1.9424 - val_loss: 2.4785 - val_mse: 10.0289
# Epoch 1965/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6918 - mse: 1.8737 - val_loss: 2.5044 - val_mse: 10.4247
# Epoch 1966/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6653 - mse: 1.7867 - val_loss: 2.4492 - val_mse: 10.0036
# Epoch 1967/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6822 - mse: 1.7900 - val_loss: 2.4870 - val_mse: 10.6071
# Epoch 1968/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7257 - mse: 1.8619 - val_loss: 2.4822 - val_mse: 10.1200
# Epoch 1969/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7090 - mse: 1.8471 - val_loss: 2.5281 - val_mse: 10.1156
# Epoch 1970/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7113 - mse: 1.8277 - val_loss: 2.5106 - val_mse: 10.5002
# Epoch 1971/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6911 - mse: 1.8328 - val_loss: 2.4283 - val_mse: 9.9873
# Epoch 1972/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6632 - mse: 1.7930 - val_loss: 2.4709 - val_mse: 10.3028
# Epoch 1973/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6769 - mse: 1.8128 - val_loss: 2.5358 - val_mse: 10.2913
# Epoch 1974/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7240 - mse: 1.8652 - val_loss: 2.4538 - val_mse: 9.9482
# Epoch 1975/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7067 - mse: 1.8828 - val_loss: 2.4907 - val_mse: 10.0569
# Epoch 1976/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6858 - mse: 1.8251 - val_loss: 2.4530 - val_mse: 9.9921
# Epoch 1977/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6849 - mse: 1.8516 - val_loss: 2.5051 - val_mse: 10.5173
# Epoch 1978/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6740 - mse: 1.8418 - val_loss: 2.4756 - val_mse: 10.3885
# Epoch 1979/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7174 - mse: 1.9004 - val_loss: 2.5264 - val_mse: 10.2957
# Epoch 1980/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7260 - mse: 1.9182 - val_loss: 2.4639 - val_mse: 10.2495
# Epoch 1981/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6877 - mse: 1.9011 - val_loss: 2.4691 - val_mse: 9.8419
# Epoch 1982/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6869 - mse: 1.8479 - val_loss: 2.4742 - val_mse: 10.2512
# Epoch 1983/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7222 - mse: 1.8791 - val_loss: 2.5281 - val_mse: 10.7927
# Epoch 1984/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6532 - mse: 1.8169 - val_loss: 2.4242 - val_mse: 9.8909
# Epoch 1985/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6770 - mse: 1.7977 - val_loss: 2.4974 - val_mse: 10.5963
# Epoch 1986/2000
# 11/11 [==============================] - 0s 5ms/step - loss: 0.6651 - mse: 1.8679 - val_loss: 2.4575 - val_mse: 10.1093
# Epoch 1987/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7068 - mse: 1.8762 - val_loss: 2.5380 - val_mse: 10.3804
# Epoch 1988/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6790 - mse: 1.8184 - val_loss: 2.4557 - val_mse: 10.0831
# Epoch 1989/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7166 - mse: 1.8357 - val_loss: 2.4797 - val_mse: 10.4438
# Epoch 1990/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7073 - mse: 1.9000 - val_loss: 2.5013 - val_mse: 10.3713
# Epoch 1991/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6640 - mse: 1.8112 - val_loss: 2.4900 - val_mse: 10.0863
# Epoch 1992/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6715 - mse: 1.8424 - val_loss: 2.4796 - val_mse: 10.0735
# Epoch 1993/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6924 - mse: 1.8296 - val_loss: 2.5810 - val_mse: 10.6910
# Epoch 1994/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7179 - mse: 1.8242 - val_loss: 2.4755 - val_mse: 10.2834
# Epoch 1995/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7066 - mse: 1.8568 - val_loss: 2.5016 - val_mse: 10.3776
# Epoch 1996/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6657 - mse: 1.8097 - val_loss: 2.4809 - val_mse: 10.3648
# Epoch 1997/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6621 - mse: 1.7843 - val_loss: 2.4649 - val_mse: 10.2556
# Epoch 1998/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6719 - mse: 1.8687 - val_loss: 2.5127 - val_mse: 10.4440
# Epoch 1999/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7406 - mse: 1.8954 - val_loss: 2.4194 - val_mse: 9.6821
# Epoch 2000/2000
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7585 - mse: 1.9545 - val_loss: 2.5168 - val_mse: 10.6999

# %% [markdown]
# We can visualize the progress that our model makes during the training process by plotting the MSE on the training and validation set against the number of epochs.
#
# A growing gap between the training and validation MSE curves is the classic sign of overfitting. If the curves sit on top of each other but at a high value, the model is too simple or under-trained.

# %%
# plot MSE history 
plot_metric(training_history['small'])

# %% [markdown]
# The same works for the loss. We can also visualize how the loss improved during training:

# %%
# Plot loss history
plot_loss(training_history['small'])

# %% [markdown]
# If we want to evaluate the performance of our model on unseen data we can use the hold out test set we put aside at the beginning of the modeling part. Its possible to evaluate the model performance using `.evaluate` or make predictions via `.predict` and calculate the MSE using sklearn's implemenatation `mean_squared_error`. Both should return the same value.
#
# Using `.evaluate` is convenient because it computes the metrics with the exact preprocessing pipeline captured inside the model; manually calling `.predict` + `mean_squared_error` should match and is a good sanity check that no data leakage occurred.

# %%
# Evaluate the small model on test set using .evaluate
loss, mse = small_model.evaluate(X_test, y_test, verbose=2)
print(f'Model MSE: {mse}')
print('--------'*5)

# Predict values for test set
y_pred = small_model.predict(X_test)
print('MSE:', mean_squared_error(y_test, y_pred))
# Out:
# 4/4 - 0s - loss: 2.5041 - mse: 13.3603 - 38ms/epoch - 9ms/step
# Model MSE: 13.360255034324956
# ----------------------------------------
# 4/4 [==============================] - 0s 1ms/step
# MSE: 13.360255034324958
# 2026-02-05 18:42:05.320872: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.

# %% [markdown]
# ### Save checkpoints during training
#
# Training a artificial neural network can sometimes take a lot of time. Luckily, the `tf.keras.callbacks.ModelCheckpoint` callback allows you to continually save the model both during and at the end of training.
# So you can use a trained model without having to retrain it, or pick-up training where you left off in case the training process was interrupted.
#
# #### Checkpoint callback usage
# We will create a `tf.keras.callbacks.ModelCheckpoint` callback that saves weights only during training. Here we monitor `val_loss` and save only the best weights (`save_best_only=True`) to keep disk usage small. Setting `save_weights_only=True` avoids serializing the full graph; we can later rebuild the architecture from code and reload the checkpoint for quick fine-tuning.

# %%
# Define path where checkpoints should be stored
checkpoint_path = "training_1/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=0) # Set verbose != 0 if you want output during training

# %% [markdown]
# ### Medium Model
#
# We can increase the complexity of our model by adding another hidden layer and increasing the number of units to 64.
# The steps for compiling the model and training it remain the same but this time we will add the prior defined callback when we fit our model.
#
# This bump in capacity often reduces underfitting but will train more slowly. Re-using the checkpoint callback lets you stop the run early yet still keep the best epoch. Compare the new history to the small model to see whether the added parameters translate into lower validation error or just faster overfitting.

# %%
# Function for medium model architecture 
def get_compiled_medium_model():
    medium_model = tf.keras.Sequential([
      tf.keras.layers.Dense(64,kernel_initializer = 'uniform', activation='relu', input_dim = 12),
      tf.keras.layers.Dense(64,kernel_initializer = 'uniform', activation='relu'),
      tf.keras.layers.Dense(64,kernel_initializer = 'uniform', activation='relu'),
      tf.keras.layers.Dense(1,kernel_initializer = 'uniform')
    ])

    medium_model.compile(optimizer=optimizer,
                  loss='mae',
                  metrics=['mse'])
    return medium_model

# %%
# Summary of medium sized model
with tf.device('/cpu:0'):
    medium_model = get_compiled_medium_model()
    print(medium_model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 64)                832
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dense_5 (Dense)             (None, 64)                4160
#
#  dense_6 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 9217 (72.01 KB)
# Trainable params: 9217 (72.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# Train the medium model with the new callback
with tf.device('/cpu:0'):
    training_history['medium'] = medium_model.fit(X_train,
                        y_train,
                        validation_split=0.2,
                        verbose=0, 
                        steps_per_epoch=STEPS_PER_EPOCH,
                        epochs=EPOCHS,
                        callbacks=[cp_callback])  # Pass callback to training

# %%
# Visualize MSE with medium model
plot_metric(training_history['medium'])

# %%
# Visualize loss with medium model
plot_loss(training_history['medium'])

# %%
# Evaluate the medium model on test set using .evaluate
loss, mse = medium_model.evaluate(X_test, y_test, verbose=2)
print(f'Model MSE: {mse}')
# Out:
# 4/4 - 0s - loss: 2.6404 - mse: 16.5269 - 44ms/epoch - 11ms/step
# Model MSE: 16.526856491507974

# %% [markdown]
# ### Large Model
#
# Let's further increase the architecture of our model. We'll add another layer and increase the amount of units to 512.
#
# Models of this size can memorize the training set rapidly. Expect training loss to plummet while validation loss may start climbing sooner; this is where regularization becomes essential. Keeping the same learning rate schedule across sizes makes the comparison fair.

# %%
# Function for large model architecture 
def get_compiled_large_model():
    large_model = tf.keras.Sequential([
      tf.keras.layers.Dense(512,kernel_initializer = 'uniform', activation='relu', input_dim = 12),
      tf.keras.layers.Dense(512,kernel_initializer = 'uniform', activation='relu'),
      tf.keras.layers.Dense(512,kernel_initializer = 'uniform', activation='relu'),
      tf.keras.layers.Dense(512,kernel_initializer = 'uniform', activation='relu'),
      tf.keras.layers.Dense(1,kernel_initializer = 'uniform')
    ])

    large_model.compile(optimizer=optimizer,
                  loss='mae',
                  metrics=['mse'])
    return large_model

# %%
# Summary of large sized model
with tf.device('/cpu:0'):
    large_model = get_compiled_large_model()
    print(large_model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 512)               6656
#
#  dense_8 (Dense)             (None, 512)               262656
#
#  dense_9 (Dense)             (None, 512)               262656
#
#  dense_10 (Dense)            (None, 512)               262656
#
#  dense_11 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 795137 (6.07 MB)
# Trainable params: 795137 (6.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# Train the model with the new callback
with tf.device('/cpu:0'):
    training_history['large'] = large_model.fit(X_train,
                        y_train,
                        validation_split=0.2,
                        verbose=0,
                        steps_per_epoch=STEPS_PER_EPOCH,
                        epochs=EPOCHS)

# %%
# Visualize MSE with large model
plot_metric(training_history['large'])

# %%
# Visualize loss with large model
plot_loss(training_history['large'])

# %%
# Evaluate the large model on test set using .evaluate
loss, mse = large_model.evaluate(X_test, y_test, verbose=2)
print(f'Model MSE: {mse}')
# Out:
# 4/4 - 0s - loss: 2.2996 - mse: 12.2858 - 49ms/epoch - 12ms/step
# Model MSE: 12.285848431110336

# %% [markdown]
# ## Strategies to prevent overfitting
#
# ### Regularization
#
# You may be familiar with Occam's Razor principle: given two explanations for something, the explanation most likely to be correct is the "simplest" one, the one that makes the least amount of assumptions. This also applies to the models learned by neural networks: given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.
#
# In the next section we will try out one form of **regularization**. Hopefully, you all are familiar with L1 and L2 regularization as we talked about it several times during the bootcamp. Nevertheless, let's refresh the general concepts before we move on:
#
# We can apply regularization techniques in order generate a simpler model to prevent overfitting. A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether). Thus a common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular". It is done by adding to the loss function of the network a cost associated with having large weights. This cost comes in two flavors:
#
# * [L1 regularization](https://developers.google.com/machine-learning/glossary/#L1_regularization), where the cost added is proportional to the absolute value of the weights coefficients (i.e. to what is called the "L1 norm" of the weights).
#
# * [L2 regularization](https://developers.google.com/machine-learning/glossary/#L2_regularization), where the cost added is proportional to the square of the value of the weights coefficients (i.e. to what is called the squared "L2 norm" of the weights). L2 regularization is also called weight decay in the context of neural networks. Don't let the different name confuse you: weight decay is mathematically the exact same as L2 regularization.
#
# L1 regularization pushes weights towards exactly zero encouraging a sparse model. L2 regularization will penalize the weights parameters without making them sparse since the penalty goes to zero for small weights - one reason why L2 is more common.
#
# In `tf.keras`, weight regularization is added by passing weight regularizer instances to layers as keyword arguments. Let's add L2 weight regularization to our large model from above:

# %%
# Large model with additional L2 regularization
def get_compiled_l2_model():
    l2_model = tf.keras.Sequential([
      tf.keras.layers.Dense(512,kernel_initializer = 'uniform', activation='relu', kernel_regularizer=regularizers.l2(0.01),
                            input_dim = 12),
      tf.keras.layers.Dense(512,kernel_initializer = 'uniform', activation='relu', kernel_regularizer=regularizers.l2(0.01)),
      tf.keras.layers.Dense(512,kernel_initializer = 'uniform', activation='relu', kernel_regularizer=regularizers.l2(0.01)),
      tf.keras.layers.Dense(512,kernel_initializer = 'uniform', activation='relu', kernel_regularizer=regularizers.l2(0.01)),
      tf.keras.layers.Dense(1,kernel_initializer = 'uniform')
    ])

    l2_model.compile(optimizer=optimizer,
                  loss='mae',
                  metrics=['mse'])
    return l2_model

# %% [markdown]
# `l2(0.01)` means that every coefficient in the weight matrix of the layer will add `0.01 * weight_coefficient_value**2` to the total **loss** of the network.
#
# If you still see overfitting, increase the coefficient (for example to `l2(0.02)`). If training stalls, decrease it. The L2 term is applied per layer, so you can regularize only the dense layers that carry most of the parameters instead of every layer.

# %%
# Summary of model architecture
with tf.device('/cpu:0'):
    l2_model = get_compiled_l2_model()
    print(l2_model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 512)               6656
#
#  dense_13 (Dense)            (None, 512)               262656
#
#  dense_14 (Dense)            (None, 512)               262656
#
#  dense_15 (Dense)            (None, 512)               262656
#
#  dense_16 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 795137 (6.07 MB)
# Trainable params: 795137 (6.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# Train regularized model
with tf.device('/cpu:0'):
    training_history['l2'] = l2_model.fit(X_train,
                        y_train,
                        validation_split=0.2,
                        verbose=0,
                        steps_per_epoch=STEPS_PER_EPOCH,                                      
                        epochs=EPOCHS)

# %%
# Visualize MSE with l2 model
plot_metric(training_history['l2'])

# %%
# Visualize loss with l2 model
plot_loss(training_history['l2'])

# %%
# Evaluate the regularized model
loss, mse = l2_model.evaluate(X_test, y_test, verbose=2)
print(f'Model MSE: {mse}')
# Out:
# 4/4 - 0s - loss: 2.3639 - mse: 10.0298 - 51ms/epoch - 13ms/step
# Model MSE: 10.029762958717559

# %% [markdown]
# As you can see, the "L2" regularized model is now much more competitive with the the "Medium" model. This "L2" model is also much more resistant to overfitting than the "Big" model it was based on despite having the same number of parameters.

# %% [markdown]
# ### Dropout
#
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks, developed by Hinton and his students at the University of Toronto.
#
# The intuitive explanation for dropout is that because individual nodes in the network cannot rely on the output of the others, each node must output features that are useful on their own.
#
# Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training. Let's say a given layer would normally have returned a vector [0.2, 0.5, 1.3, 0.8, 1.1] for a given input sample during training; after applying dropout, this vector will have a few zero entries distributed at random, e.g. [0, 0.5, 1.3, 0, 1.1].
#
# The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5. At test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.
#
# In `tf.keras` you can introduce dropout in a network via the Dropout layer, which gets applied to the output of layer right before.
#
# Let's add a Dropout layer after each dense layer in our network to see how they influence our models performance.
#
# Dropout usually slows convergence a bit because the network sees a noisier view of itself each batch. That's expected—look for validation curves that are smoother and peak later, indicating better generalization. You can sweep rates like 0.2, 0.3, 0.5 to see the trade-off between regularization strength and training speed.

# %%
# Large model with additional dropout layer
def get_compiled_dropout_model():
    dropout_model = tf.keras.Sequential([
      tf.keras.layers.Dense(512,kernel_initializer = 'uniform', activation='relu', input_dim = 12),
      tf.keras.layers.Dropout(0.25),
      tf.keras.layers.Dense(512,kernel_initializer = 'uniform', activation='relu'),
      tf.keras.layers.Dropout(0.25),
      tf.keras.layers.Dense(512,kernel_initializer = 'uniform', activation='relu'),
      tf.keras.layers.Dropout(0.25),
      tf.keras.layers.Dense(512,kernel_initializer = 'uniform', activation='relu'),
      tf.keras.layers.Dropout(0.25),
      tf.keras.layers.Dense(1,kernel_initializer = 'uniform')
    ])

    dropout_model.compile(optimizer=optimizer,
                  loss='mae',
                  metrics=['mse'])
    return dropout_model

# %%
# Summary of model architecture
with tf.device('/cpu:0'):
    dropout_model = get_compiled_dropout_model()
    print(dropout_model.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_17 (Dense)            (None, 512)               6656
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_18 (Dense)            (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_19 (Dense)            (None, 512)               262656
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_20 (Dense)            (None, 512)               262656
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_21 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 795137 (6.07 MB)
# Trainable params: 795137 (6.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# Train dropout model
with tf.device('/cpu:0'):
    training_history['dropout'] = dropout_model.fit(X_train,
                        y_train,
                        validation_split=0.2,
                        verbose=0,
                        steps_per_epoch=STEPS_PER_EPOCH,
                        epochs=EPOCHS)

# %%
# Visualize MSE with dropout model
plot_metric(training_history['dropout'])

# %%
# Visualize loss with dropout model
plot_loss(training_history['dropout'])

# %%
# Evaluate the dropout model
loss, mse = dropout_model.evaluate(X_test, y_test, verbose=2)
print(f'Model MSE: {mse}')
# Out:
# 4/4 - 0s - loss: 2.0379 - mse: 9.2475 - 53ms/epoch - 13ms/step
# Model MSE: 9.247540473132506

# %%
# Large model with additional dropout layer 0.5
def get_compiled_dropout_model_05():
    dropout_model_05 = tf.keras.Sequential([
      tf.keras.layers.Dense(512,kernel_initializer = 'uniform', activation='relu', input_dim = 12),
      tf.keras.layers.Dropout(0.5),
      tf.keras.layers.Dense(512,kernel_initializer = 'uniform', activation='relu'),
      tf.keras.layers.Dropout(0.5),
      tf.keras.layers.Dense(512,kernel_initializer = 'uniform', activation='relu'),
      tf.keras.layers.Dropout(0.5),
      tf.keras.layers.Dense(512,kernel_initializer = 'uniform', activation='relu'),
      tf.keras.layers.Dropout(0.5),
      tf.keras.layers.Dense(1,kernel_initializer = 'uniform')
    ])

    dropout_model_05.compile(optimizer=optimizer,
                  loss='mae',
                  metrics=['mse'])
    return dropout_model_05

# Summary of model architecture
with tf.device('/cpu:0'):
    dropout_model_05 = get_compiled_dropout_model()
    print(dropout_model_05.summary())
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_22 (Dense)            (None, 512)               6656
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_23 (Dense)            (None, 512)               262656
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_24 (Dense)            (None, 512)               262656
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense_25 (Dense)            (None, 512)               262656
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_26 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 795137 (6.07 MB)
# Trainable params: 795137 (6.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# Train dropout model
with tf.device('/cpu:0'):
    training_history['dropout05'] = dropout_model_05.fit(X_train,
                        y_train,
                        validation_split=0.2,
                        verbose=0,
                        steps_per_epoch=STEPS_PER_EPOCH,
                        epochs=EPOCHS)
    
# Visualize MSE with dropout model
plot_metric(training_history['dropout05'])

# %%
# Visualize loss with dropout model
plot_loss(training_history['dropout05'])

# %% [markdown]
# ### Combine L2 and Dropout
#
# It's also possible and common to combine different regularization techniques in one model.
#
# Combining both lets L2 keep weights small while dropout combats co-adaptation between neurons. Start with the same dropout rate you found reasonable above and a slightly smaller L2 coefficient to avoid over-regularizing.

# %%
# Large model with additional dropout layer and L2 regularization
def get_compiled_l2_dropout_model():
    l2_dropout_model = tf.keras.Sequential([
      tf.keras.layers.Dense(512,kernel_initializer = 'uniform', activation='relu', kernel_regularizer=regularizers.l2(0.01),
                            input_dim = 12),
      tf.keras.layers.Dropout(0.25),
      tf.keras.layers.Dense(512,kernel_initializer = 'uniform', activation='relu', kernel_regularizer=regularizers.l2(0.01)),
      tf.keras.layers.Dropout(0.25),
      tf.keras.layers.Dense(512,kernel_initializer = 'uniform', activation='relu', kernel_regularizer=regularizers.l2(0.01)),
      tf.keras.layers.Dropout(0.25),
      tf.keras.layers.Dense(512,kernel_initializer = 'uniform', activation='relu', kernel_regularizer=regularizers.l2(0.01)),
      tf.keras.layers.Dropout(0.25),
      tf.keras.layers.Dense(1,kernel_initializer = 'uniform')
    ])

    l2_dropout_model.compile(optimizer=optimizer,
                  loss='mae',
                  metrics=['mse'])
    return l2_dropout_model

# %%
# Summary of model architecture
with tf.device('/cpu:0'):
    l2_dropout_model = get_compiled_l2_dropout_model()
    print(l2_dropout_model.summary())
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_27 (Dense)            (None, 512)               6656
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  dense_28 (Dense)            (None, 512)               262656
#
#  dropout_9 (Dropout)         (None, 512)               0
#
#  dense_29 (Dense)            (None, 512)               262656
#
#  dropout_10 (Dropout)        (None, 512)               0
#
#  dense_30 (Dense)            (None, 512)               262656
#
#  dropout_11 (Dropout)        (None, 512)               0
#
#  dense_31 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 795137 (6.07 MB)
# Trainable params: 795137 (6.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# Train the model
with tf.device('/cpu:0'):
    training_history['l2_dropout'] = l2_dropout_model.fit(X_train,
                        y_train,
                        validation_split=0.2,
                        verbose=0,
                        steps_per_epoch=STEPS_PER_EPOCH,
                        epochs=EPOCHS)

# %%
# Visualize MSE with dropout and l2 model
plot_metric(training_history['l2_dropout'])

# %%
# Visualize loss with dropout and l2 model
plot_loss(training_history['l2_dropout'])

# %%
# Evaluate the dropout-l2 model
loss, mse = l2_dropout_model.evaluate(X_test, y_test, verbose=2)
print(f'Model MSE: {mse}')
# Out:
# 4/4 - 0s - loss: 2.9123 - mse: 11.5326 - 53ms/epoch - 13ms/step
# Model MSE: 11.532568029843349

# %% [markdown]
# ## Visualize results
#
# We can use the `tfdocs.plots.HistoryPlotter` to plot and compare all the results of our models.
#
# Pass the `training_history` dictionary to `HistoryPlotter.plot` to overlay runs. The helper converts the stored histories to Pandas DataFrames, so the x-axis is epochs and the legend uses the dictionary keys (e.g. `"small"`, `"medium"`, `"large-l2"`). This makes it easy to add more experiments without rewriting plotting code.

# %%
# Instantiate HistoryPlotter
plotter = tfdocs.plots.HistoryPlotter(metric = 'mse', smoothing_std=10)

# %%
# Plot results of all models
plotter.plot(training_history)
plt.xlim([5, max(plt.xlim())])
plt.ylim([0, 50])
plt.xlabel('Epochs')
plt.title('Comparison of all models')
plt.legend(loc='upper right');

# %% [markdown]
# From the plot above we can see that the large model without any regularization and the same model with L2 regularization achieved the best performance on the train as well as validation set.
# Their performance on the test set is also better than the one of the other models we trained.

# %%
print('Large Model loss and MSE:')
loss_large, mse_large = large_model.evaluate(X_test, y_test, verbose=2)
print('----'*10)
print('Medium Model loss and MSE:')
loss_medium, mse_medium = medium_model.evaluate(X_test, y_test, verbose=2)
print('----'*10)
print('L2 Model loss and MSE:')
loss_l2, mse_l2 = l2_model.evaluate(X_test, y_test, verbose=2)
# Out:
# Large Model loss and MSE:
# 4/4 - 0s - loss: 2.2996 - mse: 12.2858 - 26ms/epoch - 7ms/step
# ----------------------------------------
# Medium Model loss and MSE:
# 4/4 - 0s - loss: 2.6404 - mse: 16.5269 - 23ms/epoch - 6ms/step
# ----------------------------------------
# L2 Model loss and MSE:
# 4/4 - 0s - loss: 2.3639 - mse: 10.0298 - 24ms/epoch - 6ms/step

# %% [markdown]
# ## Summary
#
# As we can see from our models above, the Boston housing data set is not the best choice when it comes to demonstrate overfitting. All the models are only starting to overfit the data (more or less) after training for quite some time. We can easily restrict the number of epochs to generate proper results. Nevertheless, in this notebook you have learnt some important techniques to regularize your models.
#
# Let's recap: here are the most common ways to prevent overfitting in neural networks:
#
# * Get more training data.
# * Reduce the capacity of the network.
# * Add weight regularization.
# * Add dropout.
#
# Two important approaches not covered in this guide are:
#
# * data-augmentation
# * batch normalization
#
# Remember that each method can help on its own, but often combining them can be even more effective.

# %% [markdown]
# ## Saving our model
#
# Call `model.save` to save a model's architecture, weights, and training configuration in a single file/folder. This allows you to export a model so it can be used without access to the original Python code. (Custom objects (e.g. subclassed models or layers) require special attention when saving and loading.) Since the optimizer-state is recovered, you can resume training from exactly where you left off.
#
# An entire model can be saved in two different file formats (`SavedModel` and `HDF5`). The TensorFlow `SavedModel` format is the default file format in TF2.x. However, models can be saved in `HDF5` format, too.
#
# Saving a fully-functional model is very useful—you can load them in TensorFlow.js (Saved Model, HDF5) and then train and run them in web browsers, or convert them to run on mobile devices using TensorFlow Lite (SavedModel, HDF5)
#
# Let's have a look on how you can save your model using `SavedModel`. The cell below writes a `saved_model.pb` plus weights under `saved_small_model/`; rerunning it will overwrite that folder.

# %% [markdown]
# ### SavedModel format
#
# The `SavedModel` format is another way to serialize models. Models saved in this format can be restored using `tf.keras.models.load_mode` and are compatible with TensorFlow Serving.
#
# In the next cell we will save our small model in this format.

# %%
# Save the entire large model as a SavedModel.
# !mkdir -p saved_model
large_model.save('saved_model/my_large_model')
# Out:
# INFO:tensorflow:Assets written to: saved_model/my_large_model/assets
# INFO:tensorflow:Assets written to: saved_model/my_large_model/assets

# %% [markdown]
# If you want to see how you can load the model in order to make predictions, have a look at the next notebook...
